# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.model_selection import train_test_split
# module for reading reference data
from datanooblol.extractor.data_extractor import DataExtractor
from datanooblol.experimenter.scope_data import ScopeData
from datanooblol.extractor.reference_extractor import ReferenceExtractor

# %%
dxtr = DataExtractor()
ref_xtr = ReferenceExtractor(DEBUG=False)
scope_dt = ScopeData(X_feat_grp=["geography", "monetary", "proportion","toxic"], y_feat_grp=["target"])

# %%
scope_dt.extract_reference_data.columns
# Out:
# Index(['house_id', 'event_timestamp', 'MEDV', 'load_dt', 'CHAS', 'DIS', 'RAD',
#        'TAX', 'B', 'INDUS', 'LSTAT', 'PTRATIO', 'RM', 'ZN', 'NOX'],
#       dtype='object')

# %%
scope_dt.extract_reference_data
# Out:
#       house_id           event_timestamp  MEDV     load_dt  CHAS     DIS  RAD  \
# 1014       439 2022-04-01 00:00:00+00:00   8.4  2022-04-01     0  1.8206   24
# 1011       472 2022-04-01 00:00:00+00:00  19.6  2022-04-01     0  3.0993   24
# 1008       435 2022-04-01 00:00:00+00:00  11.7  2022-04-01     0  2.2222   24
# 1005       465 2022-04-01 00:00:00+00:00  21.4  2022-04-01     0  2.9634   24
# 1002       436 2022-04-01 00:00:00+00:00  13.4  2022-04-01     0  2.1247   24
# ...        ...                       ...   ...         ...   ...     ...  ...
# 504        144 2022-04-01 00:00:00+00:00  15.6  2022-04-01     0  1.4118    5
# 501        142 2022-04-01 00:00:00+00:00  14.4  2022-04-01     0  1.4394    4
# 500        145 2022-04-01 00:00:00+00:00  11.8  2022-04-01     0  1.3459    5
# 509         77 2022-04-01 00:00:00+00:00  20.0  2022-04-01     0  4.0522    5
# 1517       506 2022-04-01 00:00:00+00:00  11.9  2022-04-01     0  2.5050    1
#
# ...

# %%
scope_dt.split_data

# %%
scope_dt.X_train.columns
# Out:
# Index(['CHAS', 'DIS', 'RAD', 'TAX', 'B', 'INDUS', 'LSTAT', 'PTRATIO', 'RM',
#        'ZN', 'NOX'],
#       dtype='object')

# %%
scope_dt.X_train
# Out:
#       house_id  CHAS     DIS  RAD    TAX       B  INDUS  LSTAT  PTRATIO  \
# 360        318     0  4.0317    4  304.0  396.90   9.90  15.94     18.4
# 271        287     0  9.0892    1  241.0  341.60   1.76  12.93     18.2
# 1080       457     0  2.5806   24  666.0   10.48  18.10  19.01     20.2
# 633        101     0  2.7778    5  384.0  394.76   8.56   9.42     20.9
# 1363        47     0  5.1004    3  233.0  396.90   6.91  14.15     17.9
# ...        ...   ...     ...  ...    ...     ...    ...    ...      ...
# 624         89     0  3.4217    2  270.0  396.90   3.41   5.50     17.8
# 426        148     0  1.4608    5  403.0  391.71  19.58  29.53     14.7
# 366        320     0  4.0019    4  304.0  396.23   9.90  12.73     18.4
# 1354        51     0  6.8147    4  243.0  395.56   5.64  13.45     16.8
# 384        126     0  1.9929    2  188.0  385.02  25.65  14.81     19.1
#
#          RM    ZN    NOX
# 360   5.782   0.0  0.544
# 271   6.230  80.0  0.385
# ...

# %%
scope_dt.y_train
# Out:
#       house_id  MEDV
# 360        318  19.8
# 271        287  20.1
# 1080       457  12.7
# 633        101  27.5
# 1363        47  20.0
# ...        ...   ...
# 624         89  23.6
# 426        148  14.6
# 366        320  21.0
# 1354        51  19.7
# 384        126  21.4
#
# [354 rows x 2 columns]

# %%
import pandas as pd
pd.read_parquet("../repository/metadata/reference/X_train.parquet")
# Out:
#       house_id  CHAS     DIS  RAD    TAX       B  INDUS  LSTAT  PTRATIO  \
# 360        318     0  4.0317    4  304.0  396.90   9.90  15.94     18.4
# 271        287     0  9.0892    1  241.0  341.60   1.76  12.93     18.2
# 1080       457     0  2.5806   24  666.0   10.48  18.10  19.01     20.2
# 633        101     0  2.7778    5  384.0  394.76   8.56   9.42     20.9
# 1363        47     0  5.1004    3  233.0  396.90   6.91  14.15     17.9
# ...        ...   ...     ...  ...    ...     ...    ...    ...      ...
# 624         89     0  3.4217    2  270.0  396.90   3.41   5.50     17.8
# 426        148     0  1.4608    5  403.0  391.71  19.58  29.53     14.7
# 366        320     0  4.0019    4  304.0  396.23   9.90  12.73     18.4
# 1354        51     0  6.8147    4  243.0  395.56   5.64  13.45     16.8
# 384        126     0  1.9929    2  188.0  385.02  25.65  14.81     19.1
#
#          RM    ZN    NOX
# 360   5.782   0.0  0.544
# 271   6.230  80.0  0.385
# ...
